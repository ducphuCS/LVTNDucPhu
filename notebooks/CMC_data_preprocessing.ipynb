# %%
import json
import pandas as pd

# %%
data = pd.read_json('coinmarketcap.json')
data
# Out:
#         id          name symbol          slug  num_market_pairs  \
# 0        1       Bitcoin    BTC       bitcoin              9551
# 1     1027      Ethereum    ETH      ethereum              5774
# 2       52           XRP    XRP           xrp               671
# 3      825        Tether   USDT        tether              9129
# 4     1831  Bitcoin Cash    BCH  bitcoin-cash               579
# ...    ...           ...    ...           ...               ...
# 3846  7715     Wish Coin    WIS     wish-coin                 3
# 3847  7746   Felixo Coin    FLX   felixo-coin                 1
# 3848  7748      BSC FARM    BSC      bsc-farm                 3
# 3849  7767   Wrapped ZEC   WZEC   wrapped-zec                 1
# 3850  7784         BLink  BLINK         blink                 1
#
#                     date_added  \
# 0     2013-04-28T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2013-08-04T00:00:00.000Z
# 3     2015-02-25T00:00:00.000Z
# 4     2017-07-23T00:00:00.000Z
# ...

# %%
with open('coinmarketcap.json', 'r') as f:
    data_json = json.load(f)

# %%
data_json
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 9551,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels'],
#   'max_supply': 21000000,
#   'circulating_supply': 18555650,
#   'total_supply': 18555650,
#   'platform': None,
#   'cmc_rank': 1,
#   'last_updated': '2020-11-27T12:14:02.000Z',
#   'quote': {'USD': {'price': 16866.360753443947,
#     'volume_24h': 48467769388.66095,
#     'percent_change_1h': 0.54015354,
#     'percent_change_24h': -2.95873772,
#     'percent_change_7d': -7.58557203,
#     'market_cap': 312966286914.64215,
#     'last_updated': '2020-11-27T12:14:02.000Z'}}},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'num_market_pairs': 5774,
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'tags': ['mineable', 'pow', 'smart-contracts'],
#   'max_supply': None,
# ...

# %%
# select name, price, volume, last updated time ... for now
price = []
name = []
volume = []
last_updated = []
for item in data_json:
    name.append(item['name'])
    volume.append(item['quote']['USD']['volume_24h'])
    price.append(item['quote']['USD']['price'])
    last_updated.append(item['last_updated'])
print(price)
# Out:
# [16866.360753443947, 508.6773198835384, 0.53245824398719, 1.0012902494302, 263.95419123574186, 12.29372815829837, 67.74602934578265, 0.13525300990963, 4.72020001708168, 27.75284008300964, 0.18602541963292, 160.6237263556531, 1.00059595326702, 2.83002634004211, 16841.959671297405, 0.028537740909, 114.66762140740278, 2.25300426117303, 0.16094763265858, 0.06242151220866, 1.32858500432183, 29.6722347938614, 16.5420435275996, 5.24936571400007, 1.00329249016964, 0.01416831656842, 89.9184085542513, 0.30276554821947, 4.00443839869319, 3.30466519130795, 0.011658533011, 61.58067072588357, 67.78249488862795, 23651.90556926516, 6.06911740183707, 6.52066043500327, 1, 0.58951227801027, 2.19903636728606, 519.5034190718293, 3.4734984817993, 0.5397924829067, 4.04952796042458, 103.13215648852226, 7.47224690471178, 0.00317718964696, 46.20910893630957, 3.87183385288688, 0.29309065301517, 0.2179262740193, 5.18519067777279, 0.00030381859376, 0.02167857755842, 1.00117737183099, 0.39387791060318, 0.30530432
# ...

# %%
name = pd.Series(name)
price = pd.Series(price)
volume = pd.Series(volume)
last_updated = pd.Series(last_updated)

# %%
df = pd.DataFrame({'Name': name, 'Price': price, 'Volume': volume, 'Last updated': last_updated})
print(df)
# Out:
#               Name         Price        Volume              Last updated
# 0          Bitcoin  16866.360753  4.846777e+10  2020-11-27T12:14:02.000Z
# 1         Ethereum    508.677320  2.035690e+10  2020-11-27T12:14:02.000Z
# 2              XRP      0.532458  2.095493e+10  2020-11-27T12:15:03.000Z
# 3           Tether      1.001290  8.587323e+10  2020-11-27T12:14:07.000Z
# 4     Bitcoin Cash    263.954191  3.577413e+09  2020-11-27T12:14:06.000Z
# ...            ...           ...           ...                       ...
# 3846     Wish Coin      0.311717  0.000000e+00  2020-11-27T12:15:06.000Z
# 3847   Felixo Coin      0.001014  0.000000e+00  2020-11-27T12:14:06.000Z
# 3848      BSC FARM      0.705266  0.000000e+00  2020-11-27T12:15:06.000Z
# 3849   Wrapped ZEC     86.137299  0.000000e+00  2020-11-27T12:14:06.000Z
# 3850         BLink      0.012115  0.000000e+00  2020-11-27T12:14:05.000Z
#
# [3851 rows x 4 columns]

# %%
df.to_csv('coinmarketcap.csv', index=False)
