# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'

# %%
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '6eb59b5b-f248-43f1-8d4b-38b2ebebd4a8',
}

# %%
session = Session()
session.headers.update(headers)

# %%
try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2020-11-27T11:18:02.632Z', 'error_code': 0, 'error_message': None, 'elapsed': 139, 'credit_count': 20, 'notice': None, 'total_count': 3851}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9550, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels'], 'max_supply': 21000000, 'circulating_supply': 18555568, 'total_supply': 18555568, 'platform': None, 'cmc_rank': 1, 'last_updated': '2020-11-27T11:16:02.000Z', 'quote': {'USD': {'price': 16857.727697161714, 'volume_24h': 49253889975.82756, 'percent_change_1h': -1.62870758, 'percent_change_24h': -2.14334746, 'percent_change_7d': -7.30690037, 'market_cap': 312804712610.1676, 'last_updated': '2020-11-27T11:16:02.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5774, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable', 'pow', 'smart-contracts'], 'max_supply': None, 'circulating_supply': 113597476.1865, 'total_supply': 113597476.1865, 'platform': None, 'cmc_rank': 2, 'last_updated': '2020-11-27T11:16:02.000Z', 'quote': {'USD': {'price': 508.7507568962068, 'volume_24h': 20799521281.18107, 'percent_change_1h': -1.18596087, 'percent_change_24h': 0.08860012, 'percent_change_7d': 2.46887785, 'market_cap': 57792801991.3807, 'last_updated': '2020-11-27T11:16:02.000Z'}}}, {'id': 52, 'name': 'XRP', 'symbol': 'XRP', 'slug': 'xrp', 'num_market_pairs': 671, 'date_added': '2013-08-04T00:00:00.000Z', 'tags': ['medium-of-exchange', 'enterprise-solutions', 'binance-chain'], 'max_supply': 100000000000, 'circulating_supply': 45348221180, 'total_supply': 99990853796, 'platform': None, 'cmc_rank': 3, 'last_updated': '2020-11-27T11:17:02.000Z', 'quote': {'USD': {'price': 0.53252589753316, 'volume_24h': 21286991011.418022, 'percent_change_1h': -0.6984293, 'percent_change_24h': 1.33124536, 'percent_change_7d': 76.9604162, 'market_cap': 24149102185.41176, 'last_updated': '2020-11-27T11:17:02.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 9129, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['store-of-value', 'payments', 'stablecoin', 'stablecoin-asset-backed'], 'max_supply': None, 'circulating_supply': 18957655236.638332, 'total_supply': 19433536999.26306, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}, 'cmc_rank': 4, 'last_updated': '2020-11-27T11:16:07.000Z', 'quote': {'USD': {'price': 1.00114199101109, 'volume_24h': 87293908597.74336, 'percent_change_1h': -0.01190446, 'percent_change_24h': -0.00060999, 'percent_change_7d': 0.0652485, 'market_cap': 18979304708.509914, 'last_updated': '2020-11-27T11:16:07.000Z'}}}, {'id': 1831, 'name': 'Bitcoin Cash', 'symbol': 'BCH', 'slug': 'bitcoin-cash', 'num_market_pairs': 579, 'date_added': '2017-07-23T00:00:00.000Z', 'tags': ['mineable', 'marketplace', 'enterprise-solutions', 'binance-chain'], 'max_supply': 21000000, 'circulating_supply': 18583731.25, 'total_supply': 18583731.25, 'platform': None, 'cmc_rank': 5, 'last_updated': '2020-11-27T11:16:06.000Z', 'quote': {'USD': {'price': 263.8185493425117, 'volume_24h': 3634975937.949609, 'percent_change_1h': -1.40029843, 'percent_change_24h': -5.19681225, 'percent_change_7d': 3.32576669, 'market_cap': 4902733019.746101, 'last_updated': '2020-11-27T11:16:06.000Z'}}}, {'id': 1975, 'name': 'Chainlink', 'symbol': 'LINK', 'slug': 'chainlink', 'num_market_pairs': 402, 'date_added': '2017-09-20T00:00:00.000Z', 'tags': ['platform', 'defi', 'oracles', 'smart-contracts', 'substrate', 'polkadot'], 'max_supply': None, 'circulating_supply': 393509556.4344445, 'total_supply': 1000000000, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'}, 'cmc_rank': 6, 'last_updated': '2020-11-27T11:16:08.000Z', 'quote': { ...

# %%
new_date = data['data']
# first item
print(new_date[0])
# Out:
# {'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9550, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels'], 'max_supply': 21000000, 'circulating_supply': 18555568, 'total_supply': 18555568, 'platform': None, 'cmc_rank': 1, 'last_updated': '2020-11-27T11:16:02.000Z', 'quote': {'USD': {'price': 16857.727697161714, 'volume_24h': 49253889975.82756, 'percent_change_1h': -1.62870758, 'percent_change_24h': -2.14334746, 'percent_change_7d': -7.30690037, 'market_cap': 312804712610.1676, 'last_updated': '2020-11-27T11:16:02.000Z'}}}
